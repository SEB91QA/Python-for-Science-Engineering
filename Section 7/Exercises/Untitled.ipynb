# %%
import numpy as np


def sphere_area(d: float):
    return np.pi * d ** 2


def sphere_volume(d: float):
    return (np.pi * d ** 3)/6


diameter = []
area = []
volume = []

for i in np.arange(1, 11):
    a = sphere_area(i)
    v = sphere_volume(i)
    diameter.append(i)
    area.append(a)
    volume.append(v)

#np.set_printoptions(formatter={'float': lambda x: format(x, '6.2f')})

diameter = np.array(diameter, dtype=int)

area = np.round(np.array(area, dtype=float), decimals=2)
volume = np.round(np.array(volume, dtype=float), decimals=2)

print('diameter' + ' ' + 'area' + ' ' + 'volume')
for i in list(zip(diameter, area, volume)):
    print(i)

print('\ndiameter' + ' ' + 'area' + '      ' + 'volume')
for i in np.arange(0, len(diameter)):
    print(f"{diameter[i]}" + '        ' + f"{area[i]}" + '      ' + f"{volume[i]}")
# Out:
# diameter area volume
# (1, 3.14, 0.52)
# (2, 12.57, 4.19)
# (3, 28.27, 14.14)
# (4, 50.27, 33.51)
# (5, 78.54, 65.45)
# (6, 113.1, 113.1)
# (7, 153.94, 179.59)
# (8, 201.06, 268.08)
# (9, 254.47, 381.7)
# (10, 314.16, 523.6)
#
# diameter area      volume
# 1        3.14      0.52
# 2        12.57      4.19
# 3        28.27      14.14
# 4        50.27      33.51
# 5        78.54      65.45
# 6        113.1      113.1
# 7        153.94      179.59
# 8        201.06      268.08
# 9        254.47      381.7
# 10        314.16      523.6

# %%
def price(a, f, cpf=1000, add=12000):
    if f <= 2:
        return a * cpf
    else:
        return a * cpf + add*(f-2)


floor46 = price(46, 1200)
floor5 = price(5, 728)

print(
    f"The total cost of an apartment on the 46th floor "
    f"with a total area of 1200 sq.ft is ${floor46:,}"
)

print(
    f"The total cost of an apartment on the 5th floor "
    f"with a total area of 728 sq.ft is ${floor5:,}"
)
# Out:
# The total cost of an apartment on the 46th floor with a total area of 1200 sq.ft is $14,422,000
# The total cost of an apartment on the 5th floor with a total area of 728 sq.ft is $8,717,000

# %%
def deriv(f, x, h=1.e-9):
    return (f(x + h) - f(x - h)) / (2. * h)


def bessel(x, n):
    if n == 0:
        return np.where(x == 0, 1, np.sin(x)/x)
    #if n == 1:
     #   if x == 0:
      #      return np.
      #  else:
       #     return (-x)*(1/x) * deriv(np.sin(x)/x, x)


for i in range(0, 11):
    print(np.round(bessel(i, 0), decimals=3), np.round(bessel(i, 1)))
# Out:
# 1.0 0
# /var/folders/78/hgt6ztdn5bvbxpk7fmt5jlfc0000gn/T/ipykernel_704/1169312255.py:7: RuntimeWarning: invalid value encountered in scalar divide
#   return np.where(x == 0, 1, np.sin(x)/x)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 16
#      12             return (-x)*(1/x) * deriv(np.sin(x)/x, x)
#      15 for i in range(0, 11):
# ---> 16     print(np.round(bessel(i, 0), decimals=3), np.round(bessel(i, 1)))
#
# Cell In[28], line 12, in bessel(x, n)
#      10     return 0
#      11 else:
# ---> 12     return (-x)*(1/x) * deriv(np.sin(x)/x, x)
#
# Cell In[28], line 2, in deriv(f, x, h)
#       1 def deriv(f, x, h=1.e-9):
# ----> 2     return (f(x + h) - f(x - h)) / (2. * h)
#
# TypeError: 'numpy.float64' object is not callable

# %%
x = np.arange(np.pi/2, 2*np.pi)
f = np.sin(x)/x

deriv(f, x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 4
#       1 x = np.arange(np.pi/2, 2*np.pi)
#       2 f = np.sin(x)/x
# ----> 4 deriv(f, x)
#
# Cell In[28], line 2, in deriv(f, x, h)
#       1 def deriv(f, x, h=1.e-9):
# ----> 2     return (f(x + h) - f(x - h)) / (2. * h)
#
# TypeError: 'numpy.ndarray' object is not callable
