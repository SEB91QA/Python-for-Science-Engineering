# %%
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib qt

plt.plot([1, 3, 2, 4, 3, 5])

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

#read data from file
xdata, ydata = np.loadtxt('wavy_pulse_data.txt', unpack=True)

#create a x and y arrays for smooth curve
x = np.linspace(-10.0, 10.0, 200)
y= np.sin(x) * np.exp(-((x / 5.0) ** 2))

#create plot
plt.figure(1, figsize=(6, 4))

plt.plot(x, y, color='green', linestyle='dashed', marker='D',
         markerfacecolor='yellow', markersize=7, markeredgecolor='C1')
#plt.plot(x, y, "-C0", label="model")  # blue line
plt.plot(xdata, ydata, "oC3", label="data")  # red circle

#label x&y axes
plt.xlabel("x")
plt.ylabel("transverse displacement")

#display legen using labels set in plot function calls
plt.legend(loc="upper right", title="legend")

#draw gray lines behind plotted data for y=0 and x=0

plt.axhline(color='gray', zorder=-1)
plt.axvline(color='gray', zorder=-1)

# save plot to file
plt.savefig("wavy_pulse.pdf")

# display plot on screen
plt.show()

# %%
import seaborn as sns

c0 = sns.color_palette()
c0
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
c = sns.color_palette("Set2")
c
# Out:
# [(0.4, 0.7607843137254902, 0.6470588235294118),
#  (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
#  (0.5529411764705883, 0.6274509803921569, 0.796078431372549),
#  (0.9058823529411765, 0.5411764705882353, 0.7647058823529411),
#  (0.6509803921568628, 0.8470588235294118, 0.32941176470588235),
#  (1.0, 0.8509803921568627, 0.1843137254901961),
#  (0.8980392156862745, 0.7686274509803922, 0.5803921568627451),
#  (0.7019607843137254, 0.7019607843137254, 0.7019607843137254)]

# %%
c1 = sns.color_palette("rocket", 4)
c1
# Out:
# [(0.29977678, 0.11356089, 0.29254823),
#  (0.63139686, 0.10067417, 0.35664819),
#  (0.90848638, 0.24568473, 0.24598324),
#  (0.96298491, 0.6126247, 0.45145074)]

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

c0 = sns.color_palette()
c1 = sns.color_palette("rocket", 4)

x1 = np.linspace(-8.0, 8.0, 200)
plt.figure(figsize=(7, 4))

for i, curvature in enumerate([0.1, 0.3, 0.9, 2.7]):
    xp = np.linspace(-8.0, 8.0, 20 * (i + 1))

    yy = 0.25 + curvature * x1 ** 2
    plt.plot(x1, yy + 0.5 * i, color=c0[i])
    plt.plot(x1, -yy - 0.5 * i, color=c1[i])

    yy = 0.25 + curvature * xp ** 2
    plt.plot(xp, yy + i/2, "o", color=c0[i], mec="black", mew=0.5)
    plt.plot(xp, -yy - i/2, "o", color=c1[i], mec="black", mew=0.5)

plt.axhline(color="gray", lw=0.5, zorder=-2)
plt.axvline(color="gray", lw=0.5, zorder=-2)
plt.xlim(-8.0, 8.0)
plt.ylim(-8.0, 8.0)
plt.text(-6.0, 7.8, "Default\n palette", va="top", ha="right")
plt.text(-6.0, -7.8, "Default\n palette", va="bottom", ha="right")
# Out:
# Text(-6.0, -7.8, 'Default\n palette')

# %%
for i, curvature in enumerate([0.1, 0.3, 0.9, 2.7]):
    print(i, curvature)
# Out:
# 0 0.1
# 1 0.3
# 2 0.9
# 3 2.7

# %%
import numpy as np
import matplotlib.pyplot as plt

# read data from file
xdata, ydata, yerror = np.loadtxt('expDecayData.txt', unpack=True)

# create theoretical fitting curve
x = np.linspace(0, 45, 128)
y = 1.1 + 3.0 * x * np.exp(-(x / 10.0) ** 2)

# create plot
plt.figure(1, figsize=(7, 4))
plt.plot(x, y, '-k', label="theory")
plt.errorbar(xdata, ydata, fmt='oC0', label="data",
             xerr=1.25, yerr=yerror, ecolor='gray')

plt.axhline(color="gray", linewidth=0.5)
plt.xlabel('x')
plt.ylabel('transverse displacement')
plt.legend(loc='upper right')

# save plot to file
plt.savefig('ExpDecay.pdf')

# display plot on screen
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.arange(0.01, 10., 0.04)
ytan = np.tan(theta)

plt.figure(figsize=(8.5, 4.2))
plt.plot(theta, ytan)
plt.savefig("tanPlot0.pdf")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.arange(0.01, 10., 0.04)
ytan = np.tan(theta)

plt.figure(figsize=(8.5, 4.2))
plt.plot(theta, ytan)
plt.ylim(-8, 8)
plt.axhline(color="gray", zorder=-1)
plt.savefig("tanPlot0.pdf")
plt.show()
